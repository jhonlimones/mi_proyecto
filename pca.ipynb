# %%
# importar librerias 
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import fbeta_score, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder

from time import time
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('mushrooms.csv')   
df.head(n=5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
# Nombre de columnas

print('Cantidad de filas y columnas:', df.shape)
print('Nombre de columnas:', df.columns)
# Out:
# Cantidad de filas y columnas: (8124, 23)
# Nombre de columnas: Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
print(df.head(5))
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# COLUMNAS, NULOS Y TIPO DE DATOS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df = pd.read_csv('mushrooms.csv')
df.describe()
'''
count = Numero de Valores nulos
unique = Numero de valores unicos
top = Valor mas frecuente
freq = Freceuncia del valor mas frecuente
'''
# Out:
# '\ncount = Numero de Valores nulos\nunique = Numero de valores unicos\ntop = Valor mas frecuente\nfreq = Freceuncia del valor mas frecuente\n'

# %% [markdown]
# Calcular el numero de nulos de cada feature

# %%
# Calculamos nulos por columna

nulos = df.isnull().sum()

# Mostramos los resultados
print(nulos)
df.replace('?', np.nan, inplace=True) # Reemplaza '?' por NaN
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# Buscar valores extraños. Para ello, ver los valores únicos en cada feature

# %%
# Creamos un nuevo dataframe con dos columnas: 'features' y 'n_values'

valores_unicos = pd.DataFrame({
    'features': df.columns,                               # Nombres de Columnas
    'n_values': [df[col].unique() for col in df.columns]  # Valores unicos de cada columna
})

# Mostramos el nuevo dataframe

print (valores_unicos)
# Out:
#                     features                              n_values
# 0                      class                                [p, e]
# 1                  cap-shape                    [x, b, s, f, k, c]
# 2                cap-surface                          [s, y, f, g]
# 3                  cap-color        [n, y, w, g, e, p, b, u, c, r]
# 4                    bruises                                [t, f]
# 5                       odor           [p, a, l, n, f, c, y, s, m]
# 6            gill-attachment                                [f, a]
# 7               gill-spacing                                [c, w]
# 8                  gill-size                                [n, b]
# 9                 gill-color  [k, n, g, p, w, h, u, e, b, r, y, o]
# 10               stalk-shape                                [e, t]
# 11                stalk-root                     [e, c, b, r, nan]
# 12  stalk-surface-above-ring                          [s, f, k, y]
# ...

# %% [markdown]
# TRATAR VALORES QUE ENTENDAMOS QUE SON NULOS
#
# Imputar valores nulos con la moda o eliminar las filas

# %%
'''
# imputar valores nulos con la moda (valor mas frecuente)
for col in df.columns:
    moda = df[col].mode([0])  # Obtiene la moda de la columna
    df [col] = df[col].fillna(moda, inplace=True)  # Rellena los valores nulos con la moda

# Verificamos que ya no queden valores nulos
print(df.isnull().sum())
'''
'''
# Eliminamos filas con valores nulos
df_clean = df.dropna()

# Verificamos que se hayan eliminado las con valores nulos
print(df_clean.isnull().sum())
'''

# Eliminar columna entera

df.drop('stalk-root', axis=1, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type',
#        'veil-color', 'ring-number', 'ring-type', 'spore-print-color',
#        'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# CLASE PREDICTORA

# %%
target = 'class'
labels = df[target]


features = df.drop(target, axis=1)  # Eliminamos clase predictora del dataset

# %% [markdown]
# TRANSFORMACION DE FEATURES
#
# Usamos la tecnica ONE HOT ENCODING - Para convertir columnas categoricas en columnas binarias.
# Usando pd.get_dummies
# Una vez codificados los datos, puedes calcular la correlacion.

# %%
print('columnas antes de transformar:')
print(features.columns)
# Out:
# columnas antes de transformar:
# Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type',
#        'veil-color', 'ring-number', 'ring-type', 'spore-print-color',
#        'population', 'habitat'],
#       dtype='object')

# %%
'''# Convertimos las columnas categoricas a binario (one-hot encoding)

categori = features.columns      # Usamos features.columns ya que cada caracteristica es categorica
features = pd.concat([features, pd.get_dummies(features[categori])], axis=1) # concatenamos las nuevas columnas binarias cob el dataframe original
features.drop(categori, axis=1, inplace=True) # Elimina funciones originales y deja solo las codificadas(binarias)

labels_dummies = pd.get_dummies(labels)['edible'] # Cambia la clase objetivo a 1 es mortal, 0 es seguro

# Mostramos el resultado en binario
print(labels_dummies.head())
#print('\nDataFRame en binario:\n', features)
#print('\nEtiquetas en binario:\n', labels)'''

featurs = pd.get_dummies(features)
print(featurs.head())
# Out:
#    cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2         True        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 0         True          False          False           True          False
# 1         True          False          False           True          False
# 2        False          False          False           True          False
# 3         True          False          False          False           True
# 4         True          False          False           True          False
#
#    ...  population_s  population_v  population_y  habitat_d  habitat_g  \
# ...

# %%
# Dividir datos de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(featurs, labels, test_size=0.33, random_state=42)

# %%
label_encoder = LabelEncoder()

# Convertir las etiquetas categóricas ('e' y 'p') a numéricas (0 y 1)
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Predecir el pipeline

def train_predict(learner, sample_size, X_train, y_train, X_test, y_test):

    results = {}
    start = time()
    learner = learner.fit(X_train[:sample_size], y_train[:sample_size])
    end = time()

    results['train_time'] = end - start

    start = time()
    predictions_test = learner.predict(X_test)
    predictions_train = learner.predict(X_train[:300])
    end = time()

    results['pred_time'] = end - start
    results['acc_train'] = accuracy_score(y_train[:300],predictions_train)
    results['acc_test'] = accuracy_score(y_test,predictions_test)
    results['f_train'] = fbeta_score(y_train[:300], predictions_train, beta=0.5)
    results['f_test'] = fbeta_score(y_test,predictions_test, beta=0.5)
    print('{} trained on - {} samples'.format(learner.__class__.__name__, sample_size))
    return results

# %% [markdown]
# ELECCION DEL MEJOR MODELO
#
# Goussain Neive Bayes
# Random Forest
# KNN

# %%
# Librerias importadas

Gauss_A = GaussianNB()
Random_B = RandomForestClassifier()
knn_C = KNeighborsClassifier()

training_length = len(X_train)
samples_1 = int(training_length * 0.01)
samples_10 = int(training_length * 0.1)
samples_100 = int(training_length * 1)

# Diccionario para almacenar datos
results = []

# Entrenamiento de los modelos y almacenamiento de los resultados
for model in [Gauss_A, Random_B, knn_C]:
    model_name = model.__class__.__name__
    for i, samples in enumerate([samples_1, samples_10, samples_100]):
        # Capturamos la precisión devuelta por la función `train_predict`
        metrics = train_predict(model, samples, X_train, y_train_encoded, X_test, y_test_encoded)
        # Obtenemos solo la precisión del conjunto de prueba
        accuracy = metrics['acc_test']  # Usamos 'acc_test' para la precisión en el test set
        # Agregamos los resultados al diccionario
        results.append({
            'Model': model_name, # Nombre del modelo
            'Fold': i + 1,       # Para indicar el fold 1, 2, o 3      
            'Samples': samples,  # numero de muestras fold
            'Accuracy': accuracy * 100 # Asumiendo que accuracy es un entre 0 y 1 multiplicamos por 100 para porcentaje
        })
# Crear un DataFrame a partir de los resultados
df_results = pd.DataFrame(results)

# Mostrar el DataFrame completo
print(df_results)

# Encontrar el modelo con mejor desempeño (maxima precision)
best_model = df_results.loc[df_results['Accuracy'].idxmax()]

# Mostrar el mejor modelo
print('\nMejor Modelo:')
print(best_model)
# Out:
# GaussianNB trained on - 54 samples
# GaussianNB trained on - 544 samples
# GaussianNB trained on - 5443 samples
# RandomForestClassifier trained on - 54 samples
# RandomForestClassifier trained on - 544 samples
# RandomForestClassifier trained on - 5443 samples
# KNeighborsClassifier trained on - 54 samples
# KNeighborsClassifier trained on - 544 samples
# KNeighborsClassifier trained on - 5443 samples
#                     Model  Fold  Samples    Accuracy
# 0              GaussianNB     1       54   96.643044
# 1              GaussianNB     2      544   90.041029
# 2              GaussianNB     3     5443   98.433420
# 3  RandomForestClassifier     1       54   96.829541
# 4  RandomForestClassifier     2      544   99.627005
# 5  RandomForestClassifier     3     5443  100.000000
# 6    KNeighborsClassifier     1       54   90.861619
# 7    KNeighborsClassifier     2      544   98.657217
# 8    KNeighborsClassifier     3     5443  100.000000
#
# Mejor Modelo:
# ...

# %% [markdown]
# EL MEJOR MODELO

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train_encoded)
# Out:
# RandomForestClassifier()

# %% [markdown]
# REFLEXIONES FINALES

# %%
# Crear una lista de tuplas a partir de zip
z = list(zip(model.feature_importances_,X_train.columns))

#Ordenar la lista
z.sort(key=lambda x:x[0], reverse=True)

# Obtener los primeros 10 elementos
top_10 = z[:10]

# imprimir los resultados

for importance, feature in top_10:
    print(f'{feature}: {importance}')
# Out:
# odor_n: 0.1515267503892561
# stalk-surface-above-ring_k: 0.06624918732367414
# odor_f: 0.06514882492624238
# gill-size_b: 0.06449805260853858
# gill-size_n: 0.05051528171760948
# gill-color_b: 0.047185305342050565
# spore-print-color_h: 0.04645310836364733
# stalk-surface-below-ring_k: 0.046239485623102435
# bruises_f: 0.02960567207431803
# stalk-surface-above-ring_s: 0.026924971093528326
